# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Datasets/Life Expectancy Data.csv'

df = pd.read_csv(file_path)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
df.shape[0]
# Out:
# 2938

# %%
df.shape[1]
# Out:
# 22

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
# checking total/overall null values in the dataset
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# checking percentage of missing data/null values
(df.isnull().sum()/df.shape[0])*100
(df.isnull().sum()/df.shape[1])*100
# Out:
# Country                               0.000000
# Year                                  0.000000
# Status                                0.000000
# Life expectancy                      45.454545
# Adult Mortality                      45.454545
# infant deaths                         0.000000
# Alcohol                             881.818182
# percentage expenditure                0.000000
# Hepatitis B                        2513.636364
# Measles                               0.000000
#  BMI                                154.545455
# under-five deaths                     0.000000
# Polio                                86.363636
# Total expenditure                  1027.272727
# Diphtheria                           86.363636
#  HIV/AIDS                             0.000000
# GDP                                2036.363636
# Population                         2963.636364
#  thinness  1-19 years               154.545455
#  thinness 5-9 years                 154.545455
# ...

# %%
# fill numerical values with mean
means = df.select_dtypes(include=np.number).mean()
df.fillna(means, inplace=True)
# fill categorical values with mode
mode = df.select_dtypes(exclude=np.number).mode()
modes = mode.iloc[0]
df[mode.columns] = df[mode.columns].fillna(modes)

# 3. Check if there are any null values left
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
# df.duplicated().sum()
# Or
if df.duplicated().values.any():
    print("There are duplicate values")
else:
    print("There are no duplicate values")
# Out:
# There are no duplicate values

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df_new = df.drop(columns='under-five deaths ', inplace=True)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
duplicate_samples = df[df.duplicated(keep=False)]
print(duplicate_samples)
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life expectancy , Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles ,  BMI , Polio, Total expenditure, Diphtheria ,  HIV/AIDS, GDP, Population,  thinness  1-19 years,  thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 21 columns]

# %%
# shape of dataset after dropping a column
df.shape
# Out:
# (2938, 21)

# %%
df.rename(columns={
    'infant deaths': 'Infant deaths',
    'percentage expenditure': 'Percentage expenditure',
    'BMI': 'BMI',
    'under-five deaths': 'Under-five deaths',
    ' HIV/AIDS': 'HIV/AIDS',
    ' thinness  1-19 years': 'Thinness 1-19 years',
    ' thinness 5-9 years': 'Thinness 5-9 years',
    'Diphtheria ': 'Diphtheria',

}, inplace=True)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
life_expectancy_by_country = df.groupby('Country')['Life expectancy '].mean()
life_expectancy_by_country
# Out:
# Country
# Afghanistan                           58.19375
# Albania                               75.15625
# Algeria                               73.61875
# Angola                                49.01875
# Antigua and Barbuda                   75.05625
#                                         ...
# Venezuela (Bolivarian Republic of)    73.38750
# Viet Nam                              74.77500
# Yemen                                 63.86250
# Zambia                                53.90625
# Zimbabwe                              50.48750
# Name: Life expectancy , Length: 193, dtype: float64

# %% [markdown]
# # **Overall disease ratio**

# %%
import matplotlib.pyplot as plt
colors = ['#ff6666', '#3399ff', '#99ff99', '#ffcc66', '#9966ff']
plt.figure(figsize=(7, 7))
mylabels = ['Hepatitis B', 'HIV/AIDS', 'Measles ', 'Polio', 'Diphtheria ']
myexplode = [0.07, 0.1, 0.07, 0.07, 0.07]

values = [df['Hepatitis B'].sum(), df[' HIV/AIDS'].sum(), df['Measles '].sum(),
          df['Polio'].sum(), df['Diphtheria '].sum()]
wedges, texts, autotexts = plt.pie(values,
                                   labels=mylabels,
                                   explode=myexplode,
                                   shadow=True,
                                   autopct="%1.1f%%",
                                   startangle=140,
                                   colors=colors,
                                   wedgeprops={'edgecolor': 'black', 'linewidth': 2, 'alpha': 0.8})
for text in texts:
    text.set_fontsize(12)
    text.set_color('black')
for autotext in autotexts:
    autotext.set_fontsize(11)
    autotext.set_color('white')
    autotext.set_weight('bold')

plt.title("Overall Disease Ratio", fontsize=18, fontweight='bold')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Highest Alcohol consumption**

# %%
top_20_alcohol_countries = df.groupby('Country')['Alcohol'].sum().nlargest(20)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_20_alcohol_countries.index, y=top_20_alcohol_countries.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Total Alcohol Consumption')
plt.title('Top 20 Countries with Highest Alcohol Consumption', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-29-0312962f6512>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_20_alcohol_countries.index, y=top_20_alcohol_countries.values, palette='viridis')

# %% [markdown]
# ## **Life expectancy of top 20 countries in our dataset**

# %%
country_counts = df["Country"].value_counts().head(20)

top_countries_df = df[df["Country"].isin(country_counts.index)]

plt.figure(figsize=(12, 8))
sns.countplot(x='Country', data=top_countries_df, order=country_counts.index, palette='viridis')

plt.xticks(rotation=45, ha="right")
plt.title("Top 20 Countries by Life Expectancy")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-30-9ec4eba039da>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Country', data=top_countries_df, order=country_counts.index, palette='viridis')

# %% [markdown]
# # **Adult mortality**

# %%
top_20_adult_mortality = df.groupby('Country')['Adult Mortality'].mean().nlargest(20)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_20_adult_mortality.index, y=top_20_adult_mortality.values, palette='coolwarm')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Adult Mortality Ratio')
plt.title('Top 20 Countries with Highest Adult Mortality Ratio', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-3f381f5353db>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_20_adult_mortality.index, y=top_20_adult_mortality.values, palette='coolwarm')

# %% [markdown]
# # **Economic indicators of a random country in our dataset**

# %%
country_name = 'Brazil'
country_data = df[df['Country'] == country_name]
total_expenditure = country_data['Total expenditure'].sum()
# Check for typos and correct the column name or use an alternative method to calculate percentage expenditure.
percentage_expenditure = country_data['percentage expenditure'].mean()
gdp = country_data['GDP'].mean()
labels = ['Total Expenditure', 'Percentage Expenditure', 'GDP']
sizes = [total_expenditure, percentage_expenditure, gdp]
colors = ['#ff9999', '#66b3ff', '#99ff99']
explode = (0.1, 0, 0)

plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title(f'Economic Indicators for {country_name}', fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()
